# %% [markdown]
# # Plot Customization by Hand

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
import numpy as np

# %matplotlib inline

# %%
x = np.random.randn(1000)
plt.hist(x);

# %%
# Örnek veri oluştur
x = np.random.randn(1000)

# Figure ve axes oluştur
fig, ax = plt.subplots()

# Arkaplan rengini ayarla
ax.set_facecolor('#E6E6E6')

# Izgara çizgilerini çiz
plt.grid(color='w', linestyle='solid')

# Eksen çizgilerini gizle
for spine in ax.spines.values():
    spine.set_visible(False)

# Üst ve sağ eksen işaretlerini gizle
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()

# İşaretlerin ve etiketlerin rengini açık gri yap
ax.tick_params(axis='both', colors='gray')

# Histogramın yüzey rengini ve kenar rengini kontrol et
ax.hist(x, edgecolor='#E6E6E6', color='#EE6666')

plt.show()

# %% [markdown]
# # Changing the Defaults: rcParams

# %%
IPython_default = plt.rcParams.copy()

# %%
from matplotlib import cycler
colors = cycler('color',
                ['#EE6666', '#3388BB', '#9988DD',
                 '#EECC55', '#88BB44', '#FFBBBB'])
plt.rc('axes', facecolor='#E6E6E6', edgecolor='none',
       axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)

# %%
plt.hist(x);

# %%
for i in range(4):
    plt.plot(np.random.rand(10))

# %% [markdown]
# # Stylesheets

# %%
plt.style.available[:5]
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh']

# %%
def hist_and_lines():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 2, figsize=(11, 4))
    ax[0].hist(np.random.randn(1000))
    for i in range(3):
        ax[1].plot(np.random.rand(10))
    ax[1].legend(['a', 'b', 'c'], loc='lower left')

# %% [markdown]
# ## Default Style

# %%
# reset rcParams
plt.rcParams.update(IPython_default)

# %%
hist_and_lines()

# %% [markdown]
# ## FiveThiryEight style

# %%
with plt.style.context('fivethirtyeight'):
    hist_and_lines()

# %% [markdown]
# ## ggplot

# %%
with plt.style.context('ggplot'):
    hist_and_lines()
